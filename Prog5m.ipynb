# %% [markdown]
# Introduction to Pandas

# %%
# Creating a simple python list 
a=[1,4,3,7,5,6,3]
a
# Out:
# [1, 4, 3, 7, 5, 6, 3]

# %%
# Convert the list into an pandas object call series
import pandas as pd
a = pd.Series(a)
a
# Out:
# 0    1
# 1    4
# 2    3
# 3    7
# 4    5
# 5    6
# 6    3
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Simple series operations such as sorting,sum,max and count

# %%
a.max()
# Out:
# 7

# %%
a.min()
# Out:
# 1

# %%
a.sort_values()
# Out:
# 0    1
# 2    3
# 6    3
# 1    4
# 4    5
# 5    6
# 3    7
# dtype: int64

# %%
a.sort_values(ascending=False)
# Out:
# 3    7
# 5    6
# 4    5
# 1    4
# 6    3
# 2    3
# 0    1
# dtype: int64

# %%
a.sort_values(ascending=False,inplace=True)

# %%
a.value_counts()
# Out:
# 3    2
# 7    1
# 6    1
# 5    1
# 4    1
# 1    1
# dtype: int64

# %%
a[:1]
# Out:
# 3    7
# dtype: int64

# %%
data ={
    'apples':[3,2,0,1],
    'oranges':[3,2,0,1]
}

# %%
purchases=pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        3
# 1       2        2
# 2       0        0
# 3       1        1

# %%
purchases=pd.DataFrame(data,index=['Lily','Lola','Laila','Lisa'])

# %%
purchases
# Out:
#        apples  oranges
# Lily        3        3
# Lola        2        2
# Laila       0        0
# Lisa        1        1
